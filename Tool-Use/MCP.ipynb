# %% [markdown]
# ## MCP Tool Connector with the Claude API

# %% [markdown]
# ### Installing Utilities and Libraries

# %%
# %pip install anthropic==0.120.2 python-dotenv==1.2.2

# %% [markdown]
# ### Setting up the Environment

# %%
import os
from dotenv import load_dotenv

load_dotenv()

claude_model_name = os.getenv("CLAUDE_MODEL_NAME")
claude_api_key = os.getenv("CLAUDE_API_KEY")

# %% [markdown]
# ### Creating the Anthropic Client

# %%
import anthropic

client = anthropic.Anthropic(api_key = claude_api_key)

# %% [markdown]
# ### MCP Connector with the Messages API

# %%
response = client.beta.messages.create(
    model = claude_model_name,
    max_tokens = 4096,
    messages = [
        {
            "role": "user",
            "content": """Give me python code snippets for usage of the Microsoft Foundry SDK for the Foundry Agent Service.
            Also give citations of the web page links used to come up with the response"""
        }
    ],
    mcp_servers = [
        {
            "type": "url",
            "url": "https://learn.microsoft.com/api/mcp",
            "name": "MSLearnMCPServer"
        }
    ],
    tools = [{"type": "mcp_toolset", "mcp_server_name": "MSLearnMCPServer"}],
    betas=["mcp-client-2025-11-20"]
)


for block in response.content:
    if block.type == "text":
        print(block.text)

# %% [markdown]
# ### Inspect the Entire API Reponse

# %%
print(response.to_json())
